# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("attacks.csv",encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
#vemos que hay muchas filas NaN

# %%
df.isna().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
#Eliminamos las dos columnas Unnamed al tener su totalidad de valores nulos
df.drop(["Unnamed: 22", "Unnamed: 23"], axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# dtype: int64

# %%
df.drop_duplicates().head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
#Eliminamos las lineas con totalidad de valores nulos
df = df.dropna(axis=0, how='all')
df.isna().sum()
# Out:
# Case Number                  1
# Date                      2401
# Year                      2403
# Type                      2405
# Country                   2451
# Area                      2856
# Location                  2941
# Activity                  2945
# Name                      2611
# Sex                       2966
# Age                       5232
# Injury                    2429
# Fatal (Y/N)               2940
# Time                      5755
# Species                   5239
# Investigator or Source    2418
# pdf                       2401
# href formula              2402
# href                      2401
# Case Number.1             2401
# Case Number.2             2401
# original order            2394
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8703 entries, 0 to 25722
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
selected_columns = df[["Case Number", "Date", "Year", "Type", "Area", "Location", "Activity", "Name","Sex ", "Age", "Injury", "Fatal (Y/N)", "Time", "Investigator or Source"]]
df2 = selected_columns.copy()
df2.head()
# Out:
#   Case Number         Date    Year        Type             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8703 entries, 0 to 25722
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Area                    5847 non-null   object
#  5   Location                5762 non-null   object
#  6   Activity                5758 non-null   object
#  7   Name                    6092 non-null   object
#  8   Sex                     5737 non-null   object
#  9   Age                     3471 non-null   object
#  10  Injury                  6274 non-null   object
#  11  Fatal (Y/N)             5763 non-null   object
#  12  Time                    2948 non-null   object
#  13  Investigator or Source  6285 non-null   object
# ...

# %%
df2["Sex "].unique()
# Out:
# array(['F', 'M', nan, 'M ', 'lli', 'N', '.'], dtype=object)

# %%
sns.countplot(x=df2["Sex "])
# Out:
# <AxesSubplot:xlabel='Sex ', ylabel='count'>

# %%
df12 = df2[df2["Sex "] == "M "]
df12
# Out:
#      Case Number         Date    Year        Type        Area  \
# 563   2014.04.22  22-Apr-2014  2014.0  Unprovoked     Florida
# 1587  2005.05.15  15-May-2005  2005.0  Unprovoked  Queensland
#
#                           Location      Activity           Name Sex   Age  \
# 563   Cocoa Beach, Brevard  County      Swimming           male   M    42
# 1587      50 km east of Townsville  Spearfishing  Ben Edelstein   M   NaN
#
#                                           Injury Fatal (Y/N)   Time  \
# 563   Laceration & puncture wounds to right foot           N  15h30
# 1587                  Severe injury to lower leg           N    NaN
#
#                             Investigator or Source
# 563             R. Neale, Florida Today, 4/22/2014
# 1587  J. Anderson, Townsville Bulletin, 5/21/2005

# %%
df12 = df2[df2["Sex "] == "M "]
df12

# %%
df13 = df2[df2["Sex "] == "lli"]
df13
# Out:
#        Case Number         Date    Year        Type        Area  \
# 1624  2004.11.11.b  11-Nov-2004  2004.0  Unprovoked  California
#
#                                             Location Activity        Name  \
# 1624  Bunkers, Humboldt Bay, Eureka, Humboldt County  Surfing  Brian Kang
#
#      Sex  Age                              Injury Fatal (Y/N)   Time  \
# 1624  lli  38  Lacerations to hand, knee & thigh            N  13h30
#
#                 Investigator or Source
# 1624  R. Collier, GSAF

# %%
df14 = df2[df2["Sex "] == "N"]
df14
# Out:
#        Case Number                  Date    Year      Type             Area  \
# 4938    1934.07.11           11-Jul-1934  1934.0   Boating  New South Wales
# 6131  1801.12.18.R  Reported 18-Dec-1801  1801.0  Provoked              NaN
#
#       Location                         Activity  \
# 4938  Cronulla                          Fishing
# 6131       NaN  Standing on landed shark's tail
#
#                                              Name Sex   Age  \
# 4938  18' boat, occupants William & Leslie Newton    N  NaN
# 6131                             Stephen Pettigew    N  NaN
#
#                                                  Injury Fatal (Y/N) Time  \
# 4938  No injury to occupants Sharks continually foll...           N  NaN
# 6131                           FATAL, PROVOKED INCIDENT           Y  NaN
#
#                                  Investigator or Source
# 4938  G.P. Whitley, ref: Daily Telegraph, 7/11/1934 ...
# 6131                       The Evening Post, 12/18/1801

# %%
df15 = df2[df2["Sex "] == "."]
df15
# Out:
#        Case Number                  Date    Year          Type         Area  \
# 5437  1908.06.02.R  Reported 02-Jun-1908  1908.0  Sea Disaster  New Britain
#
#      Location Activity Name Sex   Age  \
# 5437   Matupi        .  NaN    .  NaN
#
#                                                  Injury Fatal (Y/N) Time  \
# 5437  Remains of 3 humans recovered from shark, but ...           Y  NaN
#
#          Investigator or Source
# 5437  Taranaki Herald, 6/2/1908

# %%
df16 = df2[df2["Sex "] == "NaN"]
df16
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Investigator or Source]
# Index: []
